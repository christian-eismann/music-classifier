# %%
from google.colab import drive
drive.mount('/content/drive')

# !cp '/content/drive/MyDrive/music-classifier/spectrograms.zip' .
# !unzip -q spectrograms.zip
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).
# replace spectrograms/disco/disco_92_7.pt? [y]es, [n]o, [A]ll, [N]one, [r]ename: N

# %%
import os
import pickle
import pandas as pd
import numpy as np
import torch
from torch import nn
from torch.utils.data import Dataset, DataLoader

device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')
print(f'device: {device}')
# Out:
# device: cuda

# %% [markdown]
# ## dataloader

# %%
# dataset
class GTZAN_Dataset(Dataset):
    def __init__(self, dataset, dir, transform=None, target_transform=None):
        self.labels = pd.read_csv(dataset, dtype={'file':str, 'category':int})
        self.dir = dir
        self.transform = transform
        self.target_transform = target_transform
    
    def __len__(self):
        return len(self.labels)
    
    def split_complex_numbers(self, x):
      y = torch.empty((2, 256, 256))
      y[0], y[1] = x[0].real, x[0].imag
      return y

    def __getitem__(self, idx):
        filepath = os.path.join(self.dir, self.labels.iloc[idx,0])
        spec = torch.load(filepath)
        label = self.labels.iloc[idx,1]
        
        if self.transform:
            spec = self.split_complex_numbers(spec)
        if self.target_transform:
            label = self.target_transform(label)
        
        return spec, label


# data loader
root_path = ''
gtzan_trn = GTZAN_Dataset('dataset_files_train.csv', root_path, transform=True)
gtzan_tst  = GTZAN_Dataset('dataset_files_test.csv', root_path, transform=True)
trn_dataloader = DataLoader(gtzan_trn, batch_size=128, shuffle=True)
tst_dataloader = DataLoader(gtzan_tst, batch_size=128, shuffle=True)

# %% [markdown]
# ## model definition

# %%
# model definition
class CNN(nn.Module):
     def __init__(self):
         super(CNN, self).__init__()

         self.cnn_layers = nn.Sequential(
             nn.Conv2d(2 ,   16, kernel_size=4, padding=2), nn.Tanh(), 
             nn.MaxPool2d(2), nn.BatchNorm2d(16), # 128
             nn.Conv2d(16,   32, kernel_size=4, padding=2), nn.Tanh(), 
             nn.MaxPool2d(2), nn.BatchNorm2d(32), # 64
             nn.Conv2d(32,   64, kernel_size=4, padding=2), nn.Tanh(), 
             nn.MaxPool2d(2), nn.BatchNorm2d(64),  # 32
             nn.Conv2d(64,  128, kernel_size=4, padding=2), nn.Tanh(), 
             nn.MaxPool2d(2), nn.BatchNorm2d(128), # 16
             nn.Conv2d(128, 256, kernel_size=4, padding=2), nn.Tanh(), 
             nn.MaxPool2d(2), nn.BatchNorm2d(256),  # 8
             nn.Flatten()
         )

         self.linear_layers = nn.Sequential(
             nn.Linear(8*8*256, 2048), nn.Tanh(),
             nn.Linear(2048, 2048), nn.Tanh(),
             nn.Linear(2048, 10)
         )

     def forward(self, x):
         x = self.cnn_layers(x)
         x = x.view(x.size(0), -1)
         x = self.linear_layers(x)
         return x

# %% [markdown]
# ## training

# %%
model = CNN()

learning_rate = 1e-4

model = model.to(device)
loss_fn = nn.CrossEntropyLoss()
optimizer = torch.optim.SGD(model.parameters(), lr=learning_rate)

# %%
def train_loop(dataloader, model, loss_fn, optimizer):
    running_loss, running_accu = [], []
    for batch, (X, y) in enumerate(dataloader):
        X, y = X.to(device), y.to(device)
        pred = model(X)
        loss = loss_fn(pred, y)

        optimizer.zero_grad()
        loss.backward()
        optimizer.step()
        running_loss.append(loss.item())
    training_loss = np.mean(running_loss)
    print(f'training loss: {round(training_loss, 5)}')
    return training_loss


def test_loop(dataloader, model, loss_fn):
    size = len(dataloader.dataset)
    num_batches = len(dataloader)
    test_loss, correct = 0, 0

    with torch.no_grad():
        for X, y in dataloader:
            X, y = X.to(device), y.to(device)
            pred = model(X)
            test_loss += loss_fn(pred, y).item()
            correct += (pred.argmax(1) == y).type(torch.float).sum().item()

    test_loss /= num_batches
    correct /= size
    print(f'test accuracy: {round(correct, 5)}, test loss: {round(test_loss, 5)}')
    return correct, test_loss

# %%
stat_train, stat_test = [], []

for t in range(100):
    print(f"Epoch {t+1}\n-------------------------------")
    stat_train.append(train_loop(trn_dataloader, model, loss_fn, optimizer))
    stat_test.append(test_loop(tst_dataloader, model, loss_fn))
print('\ndone.')
# Out:
# Epoch 1
# -------------------------------
# training loss: 2.23507
# test accuracy: 0.24462, test loss: 2.17781
# Epoch 2
# -------------------------------
# training loss: 2.13102
# test accuracy: 0.27014, test loss: 2.09757
# Epoch 3
# -------------------------------
# training loss: 2.06102
# test accuracy: 0.29665, test loss: 2.04222
# Epoch 4
# -------------------------------
# training loss: 2.00864
# test accuracy: 0.30265, test loss: 1.99987
# Epoch 5
# -------------------------------
# training loss: 1.96956
# test accuracy: 0.30915, test loss: 1.96431
# Epoch 6
# -------------------------------
# training loss: 1.93586
# test accuracy: 0.31616, test loss: 1.93724
# Epoch 7
# -------------------------------
# training loss: 1.90912
# test accuracy: 0.32416, test loss: 1.91407
# Epoch 8
# -------------------------------
# training loss: 1.88666
# test accuracy: 0.33467, test loss: 1.89248
# Epoch 9
# -------------------------------
# training loss: 1.86369
# test accuracy: 0.33767, test loss: 1.87265
# Epoch 10
# -------------------------------
# training loss: 1.84453
# test accuracy: 0.34967, test loss: 1.85608
# Epoch 11
# -------------------------------
# training loss: 1.82621
# test accuracy: 0.34917, test loss: 1.84323
# Epoch 12
# -------------------------------
# training loss: 1.80894
# test accuracy: 0.36068, test loss: 1.825
# Epoch 13
# -------------------------------
# training loss: 1.79519
# test accuracy: 0.36218, test loss: 1.81157
# Epoch 14
# -------------------------------
# training loss: 1.78069
# test accuracy: 0.37019, test loss: 1.80239
# Epoch 15
# -------------------------------
# training loss: 1.76874
# test accuracy: 0.37419, test loss: 1.79262
# Epoch 16
# -------------------------------
# training loss: 1.75373
# test accuracy: 0.38369, test loss: 1.77407
# Epoch 17
# -------------------------------
# training loss: 1.74222
# test accuracy: 0.38419, test loss: 1.76562
# Epoch 18
# -------------------------------
# training loss: 1.73234
# test accuracy: 0.38169, test loss: 1.75676
# Epoch 19
# -------------------------------
# training loss: 1.72134
# test accuracy: 0.38619, test loss: 1.74494
# Epoch 20
# -------------------------------
# training loss: 1.70548
# test accuracy: 0.38719, test loss: 1.74158
# Epoch 21
# -------------------------------
# training loss: 1.69723
# test accuracy: 0.3957, test loss: 1.72483
# Epoch 22
# -------------------------------
# training loss: 1.68572
# test accuracy: 0.4022, test loss: 1.71196
# Epoch 23
# -------------------------------
# training loss: 1.67628
# test accuracy: 0.4017, test loss: 1.70493
# Epoch 24
# -------------------------------
# training loss: 1.66782
# test accuracy: 0.3992, test loss: 1.69546
# Epoch 25
# -------------------------------
# training loss: 1.66031
# test accuracy: 0.4082, test loss: 1.68665
# Epoch 26
# -------------------------------
# training loss: 1.65089
# test accuracy: 0.4062, test loss: 1.67707
# Epoch 27
# -------------------------------
# training loss: 1.64021
# test accuracy: 0.4057, test loss: 1.67386
# Epoch 28
# -------------------------------
# training loss: 1.63249
# test accuracy: 0.41371, test loss: 1.66321
# Epoch 29
# -------------------------------
# training loss: 1.62412
# test accuracy: 0.41671, test loss: 1.65507
# Epoch 30
# -------------------------------
# training loss: 1.61271
# test accuracy: 0.42121, test loss: 1.6504
# Epoch 31
# -------------------------------
# training loss: 1.60771
# test accuracy: 0.42021, test loss: 1.64322
# Epoch 32
# -------------------------------
# training loss: 1.59648
# test accuracy: 0.42421, test loss: 1.63292
# Epoch 33
# -------------------------------
# training loss: 1.59308
# test accuracy: 0.42571, test loss: 1.62387
# Epoch 34
# -------------------------------
# training loss: 1.58459
# test accuracy: 0.42971, test loss: 1.61539
# Epoch 35
# -------------------------------
# training loss: 1.57583
# test accuracy: 0.43322, test loss: 1.6095
# Epoch 36
# -------------------------------
# training loss: 1.56862
# test accuracy: 0.43122, test loss: 1.60527
# Epoch 37
# -------------------------------
# training loss: 1.55909
# test accuracy: 0.43122, test loss: 1.59712
# Epoch 38
# -------------------------------
# training loss: 1.55432
# test accuracy: 0.43872, test loss: 1.58961
# Epoch 39
# -------------------------------
# training loss: 1.54772
# test accuracy: 0.44172, test loss: 1.58708
# Epoch 40
# -------------------------------
# training loss: 1.54108
# test accuracy: 0.43772, test loss: 1.58262
# Epoch 41
# -------------------------------
# training loss: 1.53283
# test accuracy: 0.44022, test loss: 1.57167
# Epoch 42
# -------------------------------
# training loss: 1.52706
# test accuracy: 0.44722, test loss: 1.56587
# Epoch 43
# -------------------------------
# training loss: 1.51916
# test accuracy: 0.45123, test loss: 1.56134
# Epoch 44
# -------------------------------
# training loss: 1.51182
# test accuracy: 0.44772, test loss: 1.5524
# Epoch 45
# -------------------------------
# training loss: 1.50773
# test accuracy: 0.45523, test loss: 1.54985
# Epoch 46
# -------------------------------
# training loss: 1.49948
# test accuracy: 0.44722, test loss: 1.54682
# Epoch 47
# -------------------------------
# training loss: 1.49194
# test accuracy: 0.45823, test loss: 1.53942
# Epoch 48
# -------------------------------
# training loss: 1.48586
# test accuracy: 0.46223, test loss: 1.52746
# Epoch 49
# -------------------------------
# training loss: 1.47912
# test accuracy: 0.45723, test loss: 1.52359
# Epoch 50
# -------------------------------
# training loss: 1.47415
# test accuracy: 0.45973, test loss: 1.51469
# Epoch 51
# -------------------------------
# training loss: 1.46804
# test accuracy: 0.45973, test loss: 1.51496
# Epoch 52
# -------------------------------
# training loss: 1.46134
# test accuracy: 0.46423, test loss: 1.50395
# Epoch 53
# -------------------------------
# training loss: 1.45344
# test accuracy: 0.46423, test loss: 1.50449
# Epoch 54
# -------------------------------
# training loss: 1.44777
# test accuracy: 0.47024, test loss: 1.49403
# Epoch 55
# -------------------------------
# training loss: 1.44667
# test accuracy: 0.46673, test loss: 1.49607
# Epoch 56
# -------------------------------
# training loss: 1.44029
# test accuracy: 0.47074, test loss: 1.48842
# Epoch 57
# -------------------------------
# training loss: 1.43137
# test accuracy: 0.47074, test loss: 1.48568
# Epoch 58
# -------------------------------
# training loss: 1.42743
# test accuracy: 0.47574, test loss: 1.47967
# Epoch 59
# -------------------------------
# training loss: 1.42366
# test accuracy: 0.47524, test loss: 1.47073
# Epoch 60
# -------------------------------
# training loss: 1.41572
# test accuracy: 0.47574, test loss: 1.46381
# Epoch 61
# -------------------------------
# training loss: 1.40943
# test accuracy: 0.48374, test loss: 1.46107
# Epoch 62
# -------------------------------
# training loss: 1.40442
# test accuracy: 0.48324, test loss: 1.4537
# Epoch 63
# -------------------------------
# training loss: 1.39619
# test accuracy: 0.47474, test loss: 1.44995
# Epoch 64
# -------------------------------
# training loss: 1.39207
# test accuracy: 0.48774, test loss: 1.44222
# Epoch 65
# -------------------------------
# training loss: 1.38606
# test accuracy: 0.49125, test loss: 1.44112
# Epoch 66
# -------------------------------
# training loss: 1.38202
# test accuracy: 0.48174, test loss: 1.43597
# Epoch 67
# -------------------------------
# training loss: 1.37717
# test accuracy: 0.48924, test loss: 1.43201
# Epoch 68
# -------------------------------
# training loss: 1.37315
# test accuracy: 0.49225, test loss: 1.42312
# Epoch 69
# -------------------------------
# training loss: 1.36671
# test accuracy: 0.49175, test loss: 1.4234
# Epoch 70
# -------------------------------
# training loss: 1.36089
# test accuracy: 0.49225, test loss: 1.41551
# Epoch 71
# -------------------------------
# training loss: 1.35547
# test accuracy: 0.49625, test loss: 1.41337
# Epoch 72
# -------------------------------
# training loss: 1.34976
# test accuracy: 0.50375, test loss: 1.41132
# Epoch 73
# -------------------------------
# training loss: 1.3436
# test accuracy: 0.49925, test loss: 1.40031
# Epoch 74
# -------------------------------
# training loss: 1.34235
# test accuracy: 0.50725, test loss: 1.3982
# Epoch 75
# -------------------------------
# training loss: 1.33809
# test accuracy: 0.50675, test loss: 1.39494
# Epoch 76
# -------------------------------
# training loss: 1.33068
# test accuracy: 0.51026, test loss: 1.38708
# Epoch 77
# -------------------------------
# training loss: 1.32848
# test accuracy: 0.50175, test loss: 1.38137
# Epoch 78
# -------------------------------
# training loss: 1.32224
# test accuracy: 0.51076, test loss: 1.38034
# Epoch 79
# -------------------------------
# training loss: 1.31808
# test accuracy: 0.51176, test loss: 1.3751
# Epoch 80
# -------------------------------
# training loss: 1.31219
# test accuracy: 0.51326, test loss: 1.37492
# Epoch 81
# -------------------------------
# training loss: 1.30898
# test accuracy: 0.52126, test loss: 1.3662
# Epoch 82
# -------------------------------
# training loss: 1.30107
# test accuracy: 0.51326, test loss: 1.35952
# Epoch 83
# -------------------------------
# training loss: 1.29869
# test accuracy: 0.51676, test loss: 1.36334
# Epoch 84
# -------------------------------
# training loss: 1.29453
# test accuracy: 0.51826, test loss: 1.35495
# Epoch 85
# -------------------------------
# training loss: 1.28819
# test accuracy: 0.52076, test loss: 1.34628
# Epoch 86
# -------------------------------
# training loss: 1.28284
# test accuracy: 0.52176, test loss: 1.34398
# Epoch 87
# -------------------------------
# training loss: 1.27938
# test accuracy: 0.52226, test loss: 1.33997
# Epoch 88
# -------------------------------
# training loss: 1.27485
# test accuracy: 0.52376, test loss: 1.34155
# Epoch 89
# -------------------------------
# training loss: 1.27223
# test accuracy: 0.53127, test loss: 1.33584
# Epoch 90
# -------------------------------
# training loss: 1.26587
# test accuracy: 0.52976, test loss: 1.32701
# Epoch 91
# -------------------------------
# training loss: 1.26152
# test accuracy: 0.53427, test loss: 1.32494
# Epoch 92
# -------------------------------
# training loss: 1.25902
# test accuracy: 0.53277, test loss: 1.32831
# Epoch 93
# -------------------------------
# training loss: 1.25275
# test accuracy: 0.53077, test loss: 1.31983
# Epoch 94
# -------------------------------
# training loss: 1.25126
# test accuracy: 0.53877, test loss: 1.31901
# Epoch 95
# -------------------------------
# training loss: 1.24892
# test accuracy: 0.54277, test loss: 1.31465
# Epoch 96
# -------------------------------
# training loss: 1.23883
# test accuracy: 0.53627, test loss: 1.30514
# Epoch 97
# -------------------------------
# training loss: 1.23718
# test accuracy: 0.54077, test loss: 1.29864
# Epoch 98
# -------------------------------
# training loss: 1.23254
# test accuracy: 0.54127, test loss: 1.30144
# Epoch 99
# -------------------------------
# training loss: 1.22657
# test accuracy: 0.54577, test loss: 1.29096
# Epoch 100
# -------------------------------
# training loss: 1.2222
# test accuracy: 0.54527, test loss: 1.28913
#
# done.

# %% [markdown]
# ## save model

# %%
with open('drive/MyDrive/music-classifier/training_statistics.pkl', 'wb') as file:
  pickle.dump([stat_train, stat_test], file)

torch.save(model.state_dict(), 'drive/MyDrive/music-classifier/nn_classifier_statedict.pt')
